# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
num1=10
num2=30
add=num1+num2
print("Num1=",num1)
print("Num2=",num2)
print("Add=",add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
bmi=int(input("Enter the Body Mass Index"))
if(bmi<18.4):
  print("Underweight")
elif(bmi<24.9):
  print("Normal weight")
elif(bmi<39.9):
  print("Overweight")
else:
  print("Obese")
# Out:
# Enter the Body Mass Index34
# Overweight
